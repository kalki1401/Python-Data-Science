# %% [markdown]
# Pillow
# - IMAGE PROCESSING
#     - IMG RESIZE
#     - IMG ROTATE
#     - CROP
#     - FLIP
#     - ENHANCE
#     - DRAW
#
# - IMG SAVE

# %%
from PIL import Image,ImageDraw,ImageEnhance

# %%
im1_path=r"C:\Users\DELL\Downloads\COOKIE.jpg"
im2_path=r"C:\Users\DELL\Downloads\download.jpg"

im1=Image.open(im1_path)
im2=Image.open(im2_path)

# %%
print(im1)
print(im2)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x2315C8D39B0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194 at 0x2315656B020>

# %%
im2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194>

# %%
im2.show() #in default image viewer

# %%
import requests  #load image from url

def load_image(url):
    return Image.open(requests.get(url,stream=True).raw)

# %%
url="data:image/jpeg;base64,..."
im4=load_image(url)
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Cell In[7], line 2
#       1 url="data:image/jpeg;base64,..."
# ----> 2 im4=load_image(url)
#
# Cell In[6], line 4, in load_image(url)
#       3 def load_image(url):
# ----> 4     return Image.open(requests.get(url,stream=True).raw)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
# ...

# %%
im2.save('img/doraemon.jpg')

# %%
im2.transpose(Image.FLIP_TOP_BOTTOM)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194>

# %%
im2.resize((750,500))
# Out:
# <PIL.Image.Image image mode=RGB size=750x500>

# %%
im2.resize((500,800))
im2.rotate(45,fillcolor="black",expand=True)
# Out:
# <PIL.Image.Image image mode=RGB size=321x322>

# %%
#enhancement of image
w,h=im2.width,im2.height
# img=im2.resize((w//2,h//2)) #reducing size by 50%
img=im2.resize((2*w,2*h))

# %%
#enhance color
en=ImageEnhance.Color(img)

# %%
en.enhance(2)
# Out:
# <PIL.Image.Image image mode=RGB size=518x388>

# %%
for i in range(-5,5):
    en.enhance(i).save(f'img/img_enhance_{i}.jpg')

# %%
en.degenerate # same as en.enhance(0)
# Out:
# <PIL.Image.Image image mode=RGB size=518x388>

# %%
#image drawingdr
from PIL import ImageFont
img=im2.resize((w*2,h*2))
dr=ImageDraw.Draw(img)
dr.circle((259,194),radius=60,fill='teal')
dr.circle((259,194),radius=100,outline='black',width=10)
font=ImageFont.truetype(r'c:\WINDOWS\Fonts\BRADHITC.TTF',50)
dr.text((259,194),"Doraemon",fill="blue",font=font,stroke_fill="yellow",stroke_width=2, anchor='ms')
start=(0,img.height//2)
end=(img.width,img.height//2)
dr.line(xy=(start,end),fill="White",width=4)
img.save('img/generated.png')
img
# Out:
# <PIL.Image.Image image mode=RGB size=518x388>

# %%
img.size
# Out:
# (518, 388)

# %%
dr

# %%
dir(dr)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_getfont',
#  '_getink',
#  '_image',
#  '_multiline_check',
#  '_multiline_spacing',
#  '_multiline_split',
#  'arc',
#  'bitmap',
#  'chord',
#  'draw',
#  'ellipse',
#  'fill',
#  'font',
#  'fontmode',
#  'getfont',
#  'im',
#  'ink',
#  'line',
#  'mode',
#  'multiline_text',
#  'multiline_textbbox',
#  'palette',
#  'pieslice',
#  'point',
#  'polygon',
#  'rectangle',
#  'regular_polygon',
#  'rounded_rectangle',
#  'shape',
#  'text',
#  'textbbox',
#  'textlength']
