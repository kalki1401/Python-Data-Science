# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\DELL\Downloads\state_wise_daily.csv")
data.head(20)
# Out:
#          Date    Date_YMD     Status  TT  AN  AP  AR  AS  BR  CH  ...  PB  RJ  \
# 0   14-Mar-20  2020-03-14  Confirmed  81   0   1   0   0   0   0  ...   1   3
# 1   14-Mar-20  2020-03-14  Recovered   9   0   0   0   0   0   0  ...   0   1
# 2   14-Mar-20  2020-03-14   Deceased   2   0   0   0   0   0   0  ...   0   0
# 3   15-Mar-20  2020-03-15  Confirmed  27   0   0   0   0   0   0  ...   0   1
# 4   15-Mar-20  2020-03-15  Recovered   4   0   0   0   0   0   0  ...   0   2
# 5   15-Mar-20  2020-03-15   Deceased   0   0   0   0   0   0   0  ...   0   0
# 6   16-Mar-20  2020-03-16  Confirmed  15   0   0   0   0   0   0  ...   0   0
# 7   16-Mar-20  2020-03-16  Recovered   1   0   0   0   0   0   0  ...   0   0
# 8   16-Mar-20  2020-03-16   Deceased   0   0   0   0   0   0   0  ...   0   0
# 9   17-Mar-20  2020-03-17  Confirmed  11   0   0   0   0   0   0  ...   0   0
# 10  17-Mar-20  2020-03-17  Recovered   1   0   0   0   0   0   0  ...   0   0
# ...

# %%
data.count()
# data.isnull().sum()
# Out:
# Date        1791
# Date_YMD    1791
# Status      1791
# TT          1791
# AN          1791
# AP          1791
# AR          1791
# AS          1791
# BR          1791
# CH          1791
# CT          1791
# DN          1791
# DD          1791
# DL          1791
# GA          1791
# GJ          1791
# HR          1791
# HP          1791
# JK          1791
# JH          1791
# KA          1791
# KL          1791
# LA          1791
# LD          1791
# MP          1791
# MH          1791
# MN          1791
# ML          1791
# MZ          1791
# NL          1791
# OR          1791
# PY          1791
# PB          1791
# RJ          1791
# SK          1791
# TN          1791
# TG          1791
# TR          1791
# UP          1791
# UT          1791
# WB          1791
# UN          1791
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(data.isnull())
plt.show()
#No Null values present in any column

# %% [markdown]
# -   Showing number of CONFIRMED,DEATHS,RECOVERED AND ACTIVE CASES IN EACH REGION

# %%
data.groupby('Status')['UP'].sum().sort_values(ascending=False)
# Out:
# Status
# Confirmed    1710168
# Recovered    1687168
# Deceased       22900
# Name: UP, dtype: int64

# %%
data.columns
# Out:
# Index(['Date', 'Date_YMD', 'Status', 'TT', 'AN', 'AP', 'AR', 'AS', 'BR', 'CH',
#        'CT', 'DN', 'DD', 'DL', 'GA', 'GJ', 'HR', 'HP', 'JK', 'JH', 'KA', 'KL',
#        'LA', 'LD', 'MP', 'MH', 'MN', 'ML', 'MZ', 'NL', 'OR', 'PY', 'PB', 'RJ',
#        'SK', 'TN', 'TG', 'TR', 'UP', 'UT', 'WB', 'UN'],
#       dtype='object')

# %%
#status of particular state
data['Status']=pd.to_datetime(data['Date'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9956\1494249162.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Status']=pd.to_datetime(data['Date'])

# %%
plt.bar(data['Status'],data['GJ'],color='red')
plt.xticks(rotation='vertical')
# Out:
# (array([18322., 18383., 18444., 18506., 18567., 18628., 18687., 18748.,
#         18809., 18871., 18932.]),
#  [Text(18322.0, 0, '2020-03'),
#   Text(18383.0, 0, '2020-05'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18506.0, 0, '2020-09'),
#   Text(18567.0, 0, '2020-11'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18687.0, 0, '2021-03'),
#   Text(18748.0, 0, '2021-05'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18871.0, 0, '2021-09'),
#   Text(18932.0, 0, '2021-11')])

# %%
plt.figure(figsize=(10,6))
plt.plot(data['Date'],data[''])
plt.xticks(rotation='vertical')
plt.show()

# %%
confirmed=data[data['status']=='Confirmed']
recovered=data[data['status']=='Recovered']

# %%
plt.figure(figsize=(10,6))
plt.plot(confirmed['State'],confirmed['Date'])
plt.xticks(rotation='vertical')
plt.show()
